# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Embedding, Dropout
from tensorflow.keras.utils import to_categorical

# %%
text = open('../dataset/text.txt', "r", encoding="utf-8").read().lower()

chars = sorted(list(set(text)))
char_to_idx = {c: i for i, c in enumerate(chars)}
idx_to_char = {i: c for i, c in enumerate(chars)}

SEQ_LENGTH = 100
VOCAB_SIZE = len(chars)

data = [char_to_idx[c] for c in text]

# %%
X = []
y = []

for i in range(len(data) - SEQ_LENGTH):
    X.append(data[i : i + SEQ_LENGTH])
    y.append(data[i + SEQ_LENGTH])

X = np.array(X).reshape(len(X), SEQ_LENGTH)
y = np.array(y)

y = to_categorical(y, num_classes=VOCAB_SIZE)

# %%
model = Sequential()
model.add(Embedding(VOCAB_SIZE, 64, input_length=SEQ_LENGTH))
model.add(LSTM(256, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(128))
model.add(Dense(VOCAB_SIZE, activation="softmax"))

model.compile(loss="categorical_crossentropy", optimizer="adam")

# %%
class TextGeneratorCallback(tf.keras.callbacks.Callback):
    def __init__(self, seed, char_to_idx, idx_to_char, seq_length=100, temps=[0.2, 0.5, 1.0]):
        super().__init__()
        self.seed = seed.lower()
        self.char_to_idx = char_to_idx
        self.idx_to_char = idx_to_char
        self.seq_length = seq_length
        self.temps = temps

    def on_epoch_end(self, epoch, logs=None):
        print(f"\n--- Epoch {epoch+1} ---")
        for temp in self.temps:
            generated = self.seed
            start_idx = max(0, len(generated) - self.seq_length)
            generated = generated[start_idx:]
            
            for _ in range(200):
                x = np.array([self.char_to_idx[c] for c in generated[-self.seq_length:]])
                x = x.reshape(1, -1)
                preds = self.model.predict(x, verbose=0)[0]

                preds = np.log(preds) / temp
                exp_preds = np.exp(preds)
                preds = exp_preds / np.sum(exp_preds)
                next_idx = np.random.choice(len(self.char_to_idx), p=preds)
                generated += self.idx_to_char[next_idx]
            
            print(f"Temperature={temp}:\n{generated}\n")

# %%
seed_text = 'In the midway of this our mortal life'
temps = [0.2, 0.5, 1.0]

text_gen_callback = TextGeneratorCallback(
    seed_text, 
    char_to_idx, 
    idx_to_char, 
    seq_length=SEQ_LENGTH, 
    temps=temps,
)

model.fit(
    X, 
    y, 
    epochs=10, 
    batch_size=128, 
    validation_split=0.2, 
    callbacks=[text_gen_callback],
)
# Out:
# Epoch 1/10
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - loss: 2.9646
# --- Epoch 1 ---
# Temperature=0.2:
# in the midway of this our mortal life the the the the the the the the the the the the the the the the the the the the fere the the he the the the the the the the the the the the the the the the the the the the the the the the the the the
#
# Temperature=0.5:
# in the midway of this our mortal life theun in in the the the meed,
# thor sre the fom sann a ans sith the ce te sod laghe inet spas the ing mes sos the orert the heen ins he neine feeregh the the mo the the an, ant se sath the the se hire
#
# Temperature=1.0:
# in the midway of this our mortal lifeud racrh beonde fase,
#
# ase,
# thure te than’ nufed boto.
# thopet,  tirl,”. suuss ipret bundt, there nerletidtumcibt insny
# lrerl giry “sietthr les af the fnerld
# ghad pinth hute
# ioth the lamd, k the ipo pe
#
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 217s 493ms/step - loss: 2.9641 - val_loss: 2.3759
# Epoch 2/10
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - loss: 2.3356
# --- Epoch 2 ---
# Temperature=0.2:
# in the midway of this our mortal life and the the the the the the the the the the me the the the the the the the the fare the the the ware the the sore the the the the the the the the the the the the the and the the the the the the the t
#
# Temperature=0.5:
# in the midway of this our mortal life of sued coopth the the pome
# the the lad and the mear the theur we sorce the core he sald wo the so fatted craith ale me if hare and the cowe beed the erend the the round
# the the mand ind the land
# sre
#
# Temperature=1.0:
# in the midway of this our mortal life. hate angwore
# thead t, wow tto manes qiweur ann secipe dy:, thae fovert
# sor’n, euecler:
# wim kear weary hecsorg i moposton mite suntpes’ad fudlre;
# the srads,
#
# thun fade
# the pele tuyt kinl,
# wh’cte galt
#
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 203s 467ms/step - loss: 2.3355 - val_loss: 2.2266
# Epoch 3/10
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - loss: 2.2056
# --- Epoch 3 ---
# Temperature=0.2:
# in the midway of this our mortal life the so the seet the so the the the the sore the the so the the so leans the the so the the the so the mist the the sore the so seeter the so sure and the so the sure the the meare the so the the the
#
# Temperature=0.5:
# in the midway of this our mortal life cire even, what thy the meed mith as foud we sirst the mesert he boume, the the seart the the prale fead were sale and in the the sade, whe sile and the i speede, the to lemerad and the the mead ay t
#
# Temperature=1.0:
# in the midway of this our mortal lifest at thou torpouce.
# amurengcesed thit inculder! ke these
# portstut
# tun mydsorty lrlourds the be te fee sey meare thou thas in they enco adsorbine colbimg cufeate
# beasio delives, in hoo dice:
# ne thear
#
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 184s 424ms/step - loss: 2.2055 - val_loss: 2.1245
# Epoch 4/10
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - loss: 2.0975
# --- Epoch 4 ---
# Temperature=0.2:
# in the midway of this our mortal life with the the so the the the the the rime and the thou the sore the the the the the the with the the the freare the crate wish the the mister the bearing the mand the sore the with the the sire the so
#
# Temperature=0.5:
# in the midway of this our mortal life these the the fume and that dear who mestar a have clome to so sure come and as i with she mime thou the breath
# i the hath bureath bowher of the enter the cerome with the more,
# the enpare erer the se
#
# Temperature=1.0:
# in the midway of this our mortal life he if le i ledings lain;
# now and pourfer ovou them-scrinl, are hal the hewirp they strit’d snest uf he mucy lom
# srefpaish hid gon’d, whith prriming there tull in the heard, fore sermeld:
# with weroclo
#
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 196s 450ms/step - loss: 2.0975 - val_loss: 2.0547
# Epoch 5/10
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - loss: 2.0176
# --- Epoch 5 ---
# Temperature=0.2:
# in the midway of this our mortal life the sours the sour the sourd the so the she the grom the shee the she the sound
# the see the sour the sore the so the seet the sour the sours the she the shall the she the greep the sourd the street t
#
# Temperature=0.5:
# in the midway of this our mortal life so the kead on the seat and to lase me that arowert then alone so me dore benender send the deal death seen the she he there ferce come then const.” the ceat the cand entrang, i beal the wath them th
#
# Temperature=1.0:
# in the midway of this our mortal life,
# then ’vean and his to i bole is rame and his dipthen oubl, and i lagh’d on hese a fom: “wo i so sut bear pans both ygrle were,
# here a as kene rave
# fol there flats, so then betred
# no the ade pire the
#
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 193s 443ms/step - loss: 2.0176 - val_loss: 1.9985
# Epoch 6/10
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - loss: 1.9459
# --- Epoch 6 ---
# Temperature=0.2:
# in the midway of this our mortal life the sast the souls,
# who conther the sate he the sace the spiring the sast the speet all the said’d, and the bead who stand the such the lead,
# and as the shall with the sain’d the sains, who the space
#
# Temperature=0.5:
# in the midway of this our mortal lifes, his one the mastart by the relles spante, what the spare were these promes, that sude of these shall for the good so the pomes
# the clouds i the one the will the were, thou all selter, and the sain’
#
# Temperature=1.0:
# in the midway of this our mortal life plest,
# whengendous a spoucht felly it othey debet it all froof!
#
# aot not these,
# hy whiths certudi
# in on on stall. in the intercess sudmid’d vort
# lenphe! borgecth otprey, fo! a jucks, the, dood, of g
#
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 199s 458ms/step - loss: 1.9459 - val_loss: 1.9421
# Epoch 7/10
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - loss: 1.9009
# --- Epoch 7 ---
# Temperature=0.2:
# in the midway of this our mortal life, when the cried the so the spome the speet the spome the great the sours the sound,
# the come the speet the spire the sould in the spare in the in the spaide the speet the speed the speat the speet in
#
# Temperature=0.5:
# in the midway of this our mortal life
# the words
# in the prose, on to that the sas the wisher and beant i speet,
# so paide the spold
# the creace i sheer with in who sound
# the spould
# the cried me the might the dowrer mand where the to spark f
#
# Temperature=1.0:
# in the midway of this our mortal life sily alrasss,
# thou thus als, criinhy in: other the chanst gold
# corlles hand at the dacrown’d in a tath
# my to hath yot heind he putes vooo.
# now
# so laninwe withal spead
# sweed
# one me spige shave:
# “sme l
#
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 218s 501ms/step - loss: 1.9009 - val_loss: 1.9154
# Epoch 8/10
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - loss: 1.8614
# --- Epoch 8 ---
# Temperature=0.2:
# in the midway of this our mortal life the space the sain,
# the prome the sain stain’d the spare the sight i strate and the spirits the said,
# that i strain me the grace the gried the space the masting the space i space the stried,
# “the to
#
# Temperature=0.5:
# in the midway of this our mortal life, and the more,
# that beaver his in more and in the side, and mown in all his the pried
# their with praith,
# the cearit so they the gried. “i mown the gaids be said’d, and the beaving of in that wail in
#
# Temperature=1.0:
# in the midway of this our mortal life
# wae is spirtige fant.
#
# me strace. and siw’d the sor nof here
# if itprery sace
# migh’d arould, that i an hiningaibs
# spiling,
# thling denilent him wurds diphs in
# ough hy parss.”—
# and vumo
# so trume hey i s
#
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 213s 489ms/step - loss: 1.8614 - val_loss: 1.8862
# Epoch 9/10
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - loss: 1.8146
# --- Epoch 9 ---
# Temperature=0.2:
# in the midway of this our mortal life art the bear the bear the gard the grom the strace the bear the steem,
# and the spirits all in the speach strain,
# who the bent the streat the sad the mand, and the brong the streach,
# then the streat t
#
# Temperature=0.5:
# in the midway of this our mortal life, and the spirit perched ascendy bead, which are the well the lanted preast i and with me bent all sad, and in was the glam’d, when and the groad the light in the dark desires,
# and where that with co’
#
# Temperature=1.0:
# in the midway of this our mortal life.
#
# when a then le, this spire,
# senpe the erblo greal, then vost,
# so where obelle prom’d to paigh’d gito
# howing, and me concent the jund’sk,
# and kis. he reser’d thear wear hrept nead. “cond mnown ind h
#
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 212s 489ms/step - loss: 1.8146 - val_loss: 1.8649
# Epoch 10/10
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - loss: 1.7801
# --- Epoch 10 ---
# Temperature=0.2:
# in the midway of this our mortal life the shore the gorth the souls
# the shall the will and with the shill the tords
# the dead in the dead with the said’d the hearn’d of the prome the prome the prom the said’d the gour’d the souls
# of the d
#
# Temperature=0.5:
# in the midway of this our mortal life,
# then that was ward in enter’d the gursed in and deturn’d was in the gerce, who beave one whom the gond in appound.”
#
# “o shill now and hears are me the and bead, and with lowt the grime with foll are
#
# Temperature=1.0:
# in the midway of this our mortal life so migh
# aminow his hear
# mare visench. he beread’d
# insuly guidt, nor revide
# the pawhan, why waint ’y from we his giltery” whull love he those brigth,
# them yreppiglon mine, who trong with this forth th
#
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 206s 474ms/step - loss: 1.7801 - val_loss: 1.8432

# %%
import json

# Загрузка данных из исходного JSON
with open('E:\User\Downloads\list_of_moscow_metro_stations.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

# Создание базовой структуры GeoJSON
geojson = {
    "type": "FeatureCollection",
    "features": []
}

# Обработка каждой станции
for station in data:
    feature = {
        "type": "Feature",
        "geometry": {
            "type": "Point",
            "coordinates": [float(station["Longitude"]), float(station["Latitude"])]
        },
        "properties": {
            "name": station["Name"],
            "line": station["Line"],
            "line_color": f"#{station['LineColor']}",  # Добавляем # к цвету
            "order": station["Order"]
        }
    }
    geojson["features"].append(feature)

# Сохранение результата
with open('moscow_metro.geojson', 'w', encoding='utf-8') as f:
    json.dump(geojson, f, ensure_ascii=False, indent=2)
