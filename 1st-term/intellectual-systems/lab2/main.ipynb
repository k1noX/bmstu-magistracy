# %% [markdown]
# # <center>Домашнее задание № 7 (демо)
# ## <center> Обучение без учителя: метод главных компонент и кластеризация

# %%
# %pip install pandas
# %pip install numpy
# %pip install seaborn
# %pip install tqdm
# %pip install scikit-learn
# %pip install matplotlib
# %pip install jupyter
# %pip install ipywidgets
# Out:
# ERROR:root:code for hash blake2b was not found.
# Traceback (most recent call last):
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 245, in <module>
#     globals()[__func_name] = __get_hash(__func_name)
#                              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 129, in __get_openssl_constructor
#     return __get_builtin_constructor(name)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 123, in __get_builtin_constructor
#     raise ValueError('unsupported hash type ' + name)
# ValueError: unsupported hash type blake2b
# ERROR:root:code for hash blake2s was not found.
# Traceback (most recent call last):
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 245, in <module>
#     globals()[__func_name] = __get_hash(__func_name)
#                              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 129, in __get_openssl_constructor
#     return __get_builtin_constructor(name)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 123, in __get_builtin_constructor
#     raise ValueError('unsupported hash type ' + name)
# ValueError: unsupported hash type blake2s
# Requirement already satisfied: pandas in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from pandas) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# ERROR:root:code for hash blake2b was not found.
# Traceback (most recent call last):
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 245, in <module>
#     globals()[__func_name] = __get_hash(__func_name)
#                              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 129, in __get_openssl_constructor
#     return __get_builtin_constructor(name)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 123, in __get_builtin_constructor
#     raise ValueError('unsupported hash type ' + name)
# ValueError: unsupported hash type blake2b
# ERROR:root:code for hash blake2s was not found.
# Traceback (most recent call last):
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 245, in <module>
#     globals()[__func_name] = __get_hash(__func_name)
#                              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 129, in __get_openssl_constructor
#     return __get_builtin_constructor(name)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 123, in __get_builtin_constructor
#     raise ValueError('unsupported hash type ' + name)
# ValueError: unsupported hash type blake2s
# Requirement already satisfied: numpy in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (2.1.2)
# Note: you may need to restart the kernel to use updated packages.
# ERROR:root:code for hash blake2b was not found.
# Traceback (most recent call last):
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 245, in <module>
#     globals()[__func_name] = __get_hash(__func_name)
#                              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 129, in __get_openssl_constructor
#     return __get_builtin_constructor(name)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 123, in __get_builtin_constructor
#     raise ValueError('unsupported hash type ' + name)
# ValueError: unsupported hash type blake2b
# ERROR:root:code for hash blake2s was not found.
# Traceback (most recent call last):
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 245, in <module>
#     globals()[__func_name] = __get_hash(__func_name)
#                              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 129, in __get_openssl_constructor
#     return __get_builtin_constructor(name)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 123, in __get_builtin_constructor
#     raise ValueError('unsupported hash type ' + name)
# ValueError: unsupported hash type blake2s
# Requirement already satisfied: seaborn in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from seaborn) (2.1.2)
# Requirement already satisfied: pandas>=1.2 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: six>=1.5 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# ERROR:root:code for hash blake2b was not found.
# Traceback (most recent call last):
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 245, in <module>
#     globals()[__func_name] = __get_hash(__func_name)
#                              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 129, in __get_openssl_constructor
#     return __get_builtin_constructor(name)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 123, in __get_builtin_constructor
#     raise ValueError('unsupported hash type ' + name)
# ValueError: unsupported hash type blake2b
# ERROR:root:code for hash blake2s was not found.
# Traceback (most recent call last):
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 245, in <module>
#     globals()[__func_name] = __get_hash(__func_name)
#                              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 129, in __get_openssl_constructor
#     return __get_builtin_constructor(name)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 123, in __get_builtin_constructor
#     raise ValueError('unsupported hash type ' + name)
# ValueError: unsupported hash type blake2s
# Requirement already satisfied: tqdm in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (4.66.5)
# Note: you may need to restart the kernel to use updated packages.
# ERROR:root:code for hash blake2b was not found.
# Traceback (most recent call last):
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 245, in <module>
#     globals()[__func_name] = __get_hash(__func_name)
#                              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 129, in __get_openssl_constructor
#     return __get_builtin_constructor(name)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 123, in __get_builtin_constructor
#     raise ValueError('unsupported hash type ' + name)
# ValueError: unsupported hash type blake2b
# ERROR:root:code for hash blake2s was not found.
# Traceback (most recent call last):
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 245, in <module>
#     globals()[__func_name] = __get_hash(__func_name)
#                              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 129, in __get_openssl_constructor
#     return __get_builtin_constructor(name)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 123, in __get_builtin_constructor
#     raise ValueError('unsupported hash type ' + name)
# ValueError: unsupported hash type blake2s
# Requirement already satisfied: scikit-learn in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (1.5.2)
# Requirement already satisfied: numpy>=1.19.5 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from scikit-learn) (2.1.2)
# Requirement already satisfied: scipy>=1.6.0 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from scikit-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.
# ERROR:root:code for hash blake2b was not found.
# Traceback (most recent call last):
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 245, in <module>
#     globals()[__func_name] = __get_hash(__func_name)
#                              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 129, in __get_openssl_constructor
#     return __get_builtin_constructor(name)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 123, in __get_builtin_constructor
#     raise ValueError('unsupported hash type ' + name)
# ValueError: unsupported hash type blake2b
# ERROR:root:code for hash blake2s was not found.
# Traceback (most recent call last):
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 245, in <module>
#     globals()[__func_name] = __get_hash(__func_name)
#                              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 129, in __get_openssl_constructor
#     return __get_builtin_constructor(name)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 123, in __get_builtin_constructor
#     raise ValueError('unsupported hash type ' + name)
# ValueError: unsupported hash type blake2s
# Requirement already satisfied: matplotlib in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from matplotlib) (2.1.2)
# Requirement already satisfied: packaging>=20.0 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# ERROR:root:code for hash blake2b was not found.
# Traceback (most recent call last):
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 245, in <module>
#     globals()[__func_name] = __get_hash(__func_name)
#                              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 129, in __get_openssl_constructor
#     return __get_builtin_constructor(name)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 123, in __get_builtin_constructor
#     raise ValueError('unsupported hash type ' + name)
# ValueError: unsupported hash type blake2b
# ERROR:root:code for hash blake2s was not found.
# Traceback (most recent call last):
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 245, in <module>
#     globals()[__func_name] = __get_hash(__func_name)
#                              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 129, in __get_openssl_constructor
#     return __get_builtin_constructor(name)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 123, in __get_builtin_constructor
#     raise ValueError('unsupported hash type ' + name)
# ValueError: unsupported hash type blake2s
# Requirement already satisfied: jupyter in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (1.1.1)
# Requirement already satisfied: notebook in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from jupyter) (7.2.2)
# Requirement already satisfied: jupyter-console in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: nbconvert in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from jupyter) (7.16.4)
# Requirement already satisfied: ipykernel in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from jupyter) (6.29.5)
# Requirement already satisfied: ipywidgets in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from jupyter) (8.1.5)
# Requirement already satisfied: jupyterlab in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from jupyter) (4.2.5)
# Requirement already satisfied: comm>=0.1.1 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from ipykernel->jupyter) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from ipykernel->jupyter) (1.8.7)
# Requirement already satisfied: ipython>=7.23.1 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from ipykernel->jupyter) (8.28.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from ipykernel->jupyter) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from ipykernel->jupyter) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from ipykernel->jupyter) (0.1.7)
# Requirement already satisfied: nest-asyncio in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from ipykernel->jupyter) (1.6.0)
# Requirement already satisfied: packaging in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from ipykernel->jupyter) (24.1)
# Requirement already satisfied: psutil in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from ipykernel->jupyter) (6.1.0)
# Requirement already satisfied: pyzmq>=24 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from ipykernel->jupyter) (26.2.0)
# Requirement already satisfied: tornado>=6.1 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from ipykernel->jupyter) (6.4.1)
# Requirement already satisfied: traitlets>=5.4.0 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from ipykernel->jupyter) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from ipywidgets->jupyter) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from ipywidgets->jupyter) (3.0.13)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from jupyter-console->jupyter) (3.0.48)
# Requirement already satisfied: pygments in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from jupyter-console->jupyter) (2.18.0)
# Requirement already satisfied: async-lru>=1.0.0 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from jupyterlab->jupyter) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from jupyterlab->jupyter) (0.27.2)
# Requirement already satisfied: jinja2>=3.0.3 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from jupyterlab->jupyter) (3.1.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from jupyterlab->jupyter) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from jupyterlab->jupyter) (2.14.2)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from jupyterlab->jupyter) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from jupyterlab->jupyter) (0.2.4)
# Requirement already satisfied: setuptools>=40.1.0 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from jupyterlab->jupyter) (75.2.0)
# Requirement already satisfied: beautifulsoup4 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from nbconvert->jupyter) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from nbconvert->jupyter) (6.1.0)
# Requirement already satisfied: defusedxml in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from nbconvert->jupyter) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from nbconvert->jupyter) (3.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from nbconvert->jupyter) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from nbconvert->jupyter) (0.10.0)
# Requirement already satisfied: nbformat>=5.7 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from nbconvert->jupyter) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: tinycss2 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from nbconvert->jupyter) (1.3.0)
# Requirement already satisfied: six>=1.9.0 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from bleach!=5.0.0->nbconvert->jupyter) (1.16.0)
# Requirement already satisfied: webencodings in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from bleach!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: anyio in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (4.6.2.post1)
# Requirement already satisfied: certifi in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (1.0.6)
# Requirement already satisfied: idna in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (3.10)
# Requirement already satisfied: sniffio in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter) (0.14.0)
# Requirement already satisfied: decorator in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.19.1)
# Requirement already satisfied: stack-data in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (4.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (4.3.6)
# Requirement already satisfied: argon2-cffi>=21.1 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.21.0)
# Requirement already satisfied: send2trash>=1.8.2 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.0)
# Requirement already satisfied: babel>=2.10 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.16.0)
# Requirement already satisfied: json5>=0.9.0 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.9.25)
# Requirement already satisfied: jsonschema>=4.18.0 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (4.23.0)
# Requirement already satisfied: requests>=2.31 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.32.3)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from nbformat>=5.7->nbconvert->jupyter) (2.20.0)
# Requirement already satisfied: wcwidth in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter) (0.2.13)
# Requirement already satisfied: soupsieve>1.2 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from beautifulsoup4->nbconvert->jupyter) (2.6)
# Requirement already satisfied: argon2-cffi-bindings in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (21.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.20.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (6.0.2)
# Requirement already satisfied: rfc3339-validator in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.1)
# Requirement already satisfied: ptyprocess>=0.5 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->jupyter) (0.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.2.3)
# Requirement already satisfied: executing>=1.2.0 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (2.4.1)
# Requirement already satisfied: pure-eval in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (0.2.3)
# Requirement already satisfied: fqdn in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.5.1)
# Requirement already satisfied: isoduration in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.0.0)
# Requirement already satisfied: uri-template in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (24.8.0)
# Requirement already satisfied: cffi>=1.0.1 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.17.1)
# Requirement already satisfied: pycparser in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.9.0.20241003)
# Note: you may need to restart the kernel to use updated packages.
# ERROR:root:code for hash blake2b was not found.
# Traceback (most recent call last):
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 245, in <module>
#     globals()[__func_name] = __get_hash(__func_name)
#                              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 129, in __get_openssl_constructor
#     return __get_builtin_constructor(name)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 123, in __get_builtin_constructor
#     raise ValueError('unsupported hash type ' + name)
# ValueError: unsupported hash type blake2b
# ERROR:root:code for hash blake2s was not found.
# Traceback (most recent call last):
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 245, in <module>
#     globals()[__func_name] = __get_hash(__func_name)
#                              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 129, in __get_openssl_constructor
#     return __get_builtin_constructor(name)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 123, in __get_builtin_constructor
#     raise ValueError('unsupported hash type ' + name)
# ValueError: unsupported hash type blake2s
# Requirement already satisfied: ipywidgets in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (8.1.5)
# Requirement already satisfied: comm>=0.1.3 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from ipywidgets) (8.28.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from ipywidgets) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from ipywidgets) (3.0.13)
# Requirement already satisfied: decorator in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (2.18.0)
# Requirement already satisfied: stack-data in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: pure-eval in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Requirement already satisfied: six>=1.12.0 in /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from tqdm.notebook import tqdm

# %matplotlib inline
from matplotlib import pyplot as plt

plt.style.use(['seaborn-v0_8-darkgrid'])
plt.rcParams['figure.figsize'] = (12, 9)
plt.rcParams['font.family'] = 'DejaVu Sans'

from sklearn import metrics
from sklearn.cluster import AgglomerativeClustering, KMeans, SpectralClustering
from sklearn.decomposition import PCA
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.svm import LinearSVC

RANDOM_STATE = 17

# %%
X_train = np.loadtxt("data/X_train.txt")
y_train = np.loadtxt("data/y_train.txt").astype(int)

X_test = np.loadtxt("data/X_test.txt")
y_test = np.loadtxt("data/y_test.txt").astype(int)

# %%
# Проверим размерности
assert(X_train.shape == (7352, 561) and y_train.shape == (7352,))
assert(X_test.shape == (2947, 561) and y_test.shape == (2947,))

# %% [markdown]
# Для кластеризации нам не нужен вектор ответов, поэтому будем работать с объединением обучающей и тестовой выборок. Объедините *X_train* с *X_test*, а *y_train* – с *y_test*.

# %%
X = np.vstack([X_train, X_test])
y = np.hstack([y_train, y_test])

# %% [markdown]
# Определим число уникальных значений меток целевого класса.

# %%
np.unique(y)
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
n_classes = np.unique(y).size

# %% [markdown]
# [Эти метки соответствуют:](https://archive.ics.uci.edu/ml/machine-learning-databases/00240/UCI%20HAR%20Dataset.names)
# - 1 - ходьбе
# - 2 - подъему вверх по лестнице
# - 3 - спуску по лестнице
# - 4 - сидению
# - 5 - стоянию
# - 6 - лежанию
#
# *уж простите, если звучание этих существительных кажется корявым :)*

# %% [markdown]
# Отмасштабируйте выборку с помощью `StandardScaler` с параметрами по умолчанию.

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# Понижаем размерность с помощью PCA, оставляя столько компонент, сколько нужно для того, чтобы объяснить как минимум 90% дисперсии исходных (отмасштабированных) данных. Используйте отмасштабированную выборку и зафиксируйте random_state (константа RANDOM_STATE).

# %%
pca = PCA(n_components=0.9, random_state=RANDOM_STATE).fit(X_scaled)
X_pca = pca.transform(X_scaled)

# %% [markdown]
# **Вопрос 1:**<br>
# Какое минимальное число главных компонент нужно выделить, чтобы объяснить 90% дисперсии исходных (отмасштабированных) данных?

# %%
X_pca.shape
# Out:
# (10299, 65)

# %% [markdown]
# **Варианты:**
# - 56
# - 65 [+]
# - 66
# - 193

# %% [markdown]
# **Вопрос 2:**<br>
# Сколько процентов дисперсии приходится на первую главную компоненту? Округлите до целых процентов.
#
# **Варианты:**
# - 45
# - 51 [+]
# - 56
# - 61

# %%
round(float(pca.explained_variance_ratio_[0] * 100))
# Out:
# 51

# %% [markdown]
# Визуализируйте данные в проекции на первые две главные компоненты.

# %%
from matplotlib.colors import ListedColormap

labels = [
    'ходьба', 'подъем вверх по лестнице', 
    'спуск по лестнице', 'сидение', 'стояние', 'лежание'
]
colors = plt.cm.viridis(np.linspace(0, 1, 6))
cmap = ListedColormap(colors)

fig, ax = plt.subplots()
ax.scatter(X_pca[:, 0], X_pca[:, 1], c=y, cmap=cmap, s=20)

handles = []
for i, color in enumerate(colors):
    handle = plt.Line2D([0], [0], marker='o', color=color, label=labels[i])
    handles.append(handle)

ax.legend(handles=handles)

# %% [markdown]
# **Вопрос 3:**<br>
# Если все получилось правильно, Вы увидите сколько-то кластеров, почти идеально отделенных друг от друга. Какие виды активности входят в эти кластеры?<br>
#
# **Ответ:**
# - 1 кластер: все 6 активностей
# - 2 кластера: (ходьба, подъем вверх по лестнице, спуск по лестнице) и (сидение, стояние, лежание) [+]
# - 3 кластера: (ходьба), (подъем вверх по лестнице, спуск по лестнице) и (сидение, стояние, лежание)
# - 6 кластеров

# %% [markdown]
# ------------------------------

# %% [markdown]
# Сделайте кластеризацию данных методом `KMeans`, обучив модель на данных со сниженной за счет PCA размерностью. В данном случае мы подскажем, что нужно искать именно 6 кластеров, но в общем случае мы не будем знать, сколько кластеров надо искать.
#
# Параметры:
#
# - **n_clusters** = n_classes (число уникальных меток целевого класса)
# - **n_init** = 100
# - **random_state** = RANDOM_STATE (для воспроизводимости результата)
#
# Остальные параметры со значениями по умолчанию.

# %%
kmeans = KMeans(n_clusters=n_classes, n_init=100, random_state=RANDOM_STATE)
kmeans.fit(X_pca)
cluster_labels = kmeans.labels_

# %% [markdown]
# Визуализируйте данные в проекции на первые две главные компоненты. Раскрасьте точки в соответствии с полученными метками кластеров.

# %%
from matplotlib.colors import ListedColormap

labels = [
    'ходьба', 'подъем вверх по лестнице', 
    'спуск по лестнице', 'сидение', 'стояние', 'лежание'
]
colors = plt.cm.viridis(np.linspace(0, 1, 6))
cmap = ListedColormap(colors)

fig, ax = plt.subplots()
ax.scatter(X_pca[:, 0], X_pca[:, 1], c=cluster_labels, cmap=cmap, s=20)

handles = []
for i, color in enumerate(colors):
    handle = plt.Line2D([0], [0], marker='o', color=color, label=labels[i-1])
    handles.append(handle)

ax.legend(handles=handles)

# %% [markdown]
# Посмотрите на соответствие между метками кластеров и исходными метками классов и на то, какие виды активностей алгоритм `KMeans` путает.

# %%
tab = pd.crosstab(y, cluster_labels, margins=True)
tab.index = ['ходьба', 'подъем вверх по лестнице', 
             'спуск по лестнице', 'сидение', 'стояние', 'лежание', 'все']
tab.columns = ['cluster' + str(i + 1) for i in range(6)] + ['все']
tab
# Out:
#                           cluster1  cluster2  cluster3  cluster4  cluster5  \
# ходьба                           0       903       741        78         0
# подъем вверх по лестнице         0      1241       296         5         2
# спуск по лестнице                0       320       890       196         0
# сидение                       1235         1         0         0       450
# стояние                       1344         0         0         0       562
# лежание                         52         5         0         0       329
# все                           2631      2470      1927       279      1343
#
#                           cluster6    все
# ходьба                           0   1722
# подъем вверх по лестнице         0   1544
# спуск по лестнице                0   1406
# сидение                         91   1777
# стояние                          0   1906
# лежание                       1558   1944
# все                           1649  10299

# %% [markdown]
# Видим, что каждому классу (т.е. каждой активности) соответствуют несколько кластеров. Давайте посмотрим на максимальную долю объектов в классе, отнесенных к какому-то одному кластеру. Это будет простой метрикой, характеризующей, насколько легко класс отделяется от других при кластеризации.
#
# Пример: если для класса "спуск по лестнице", в котором 1406 объектов,  распределение кластеров такое:
#  - кластер 1 – 900
#  - кластер 3 – 500
#  - кластер 6 – 6,
#
# то такая доля будет 900 / 1406 $\approx$ 0.64.
#
#
# **Вопрос 4:**<br>
# Какой вид активности отделился от остальных лучше всего в терминах простой  метрики, описанной выше?<br>
#
# **Ответ:**
# - ходьба
# - стояние
# - спуск по лестнице
# - перечисленные варианты не подходят [+]

# %%
pd.Series(
    tab.iloc[:-1, :-1].max(axis=1).values / tab.iloc[:-1, -1].values,
    index=tab.index[:-1],
)
# Out:
# ходьба                      0.524390
# подъем вверх по лестнице    0.803756
# спуск по лестнице           0.633001
# сидение                     0.694992
# стояние                     0.705142
# лежание                     0.801440
# dtype: float64

# %% [markdown]
# Видно, что kMeans не очень хорошо отличает только активности друг от друга. Используйте метод локтя, чтобы выбрать оптимальное количество кластеров. Параметры алгоритма и данные используем те же, что раньше, меняем только `n_clusters`.

# %%
inertia = []
for k in tqdm(range(1, n_classes + 1)):
    kmeans = KMeans(n_clusters=k, n_init=100, random_state=RANDOM_STATE).fit(
        X_pca
    )
    inertia.append(np.sqrt(kmeans.inertia_))
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]

# %%
plt.plot(range(1, 7), inertia, marker="s")

# %%
d = {}
for k in range(2, 6):
    i = k - 1
    d[k] = (inertia[i] - inertia[i + 1]) / (inertia[i - 1] - inertia[i])
d
# Out:
# {2: np.float64(0.1734475356009401),
#  3: np.float64(0.41688555755864765),
#  4: np.float64(0.9332198909748659),
#  5: np.float64(0.6297014287707848)}

# %% [markdown]
# **Вопрос 5:**<br>
# Какое количество кластеров оптимально выбрать, согласно методу локтя?<br>
#
# **Ответ:**
# - 1
# - 2 [+]
# - 3
# - 4

# %% [markdown]
# ------------------------

# %% [markdown]
# Попробуем еще один метод кластеризации, который описывался в статье – агломеративную кластеризацию.

# %%
ag = AgglomerativeClustering(n_clusters=n_classes, 
                             linkage='ward').fit(X_pca)

# %% [markdown]
# Посчитайте Adjusted Rand Index (`sklearn.metrics`) для получившегося разбиения на кластеры и для `KMeans` с параметрами из задания к 4 вопросу.

# %%
metrics.adjusted_rand_score(y, cluster_labels)
# Out:
# 0.4198070012602345

# %%
metrics.adjusted_rand_score(y, ag.labels_)
# Out:
# 0.49362763373004886

# %% [markdown]
# **Вопрос 6:**<br>
# Отметьте все верные утверждения.<br>
#
# **Варианты:**
# - Согласно ARI, KMeans справился с кластеризацией хуже, чем Agglomerative Clustering [+]
# - Для ARI не имеет значения какие именно метки присвоены кластерам, имеет значение только разбиение объектов на кластеры [+]
# - В случае случайного разбиения на кластеры ARI будет близок к нулю [+]

# %% [markdown]
# -------------------------------

# %% [markdown]
# Можно заметить, что задача не очень хорошо решается именно как задача кластеризации, если выделять несколько кластеров (> 2). Давайте теперь решим задачу классификации, вспомнив, что данные у нас размечены.
#
# Для классификации используйте метод опорных векторов – класс `sklearn.svm.LinearSVC`. Мы в курсе отдельно не рассматривали этот алгоритм, но он очень известен, почитать про него можно, например, в материалах Евгения Соколова –  [тут](https://github.com/esokolov/ml-course-msu/blob/master/ML16/lecture-notes/Sem11_linear.pdf).
#
# Настройте для `LinearSVC` гиперпараметр `C` с помощью `GridSearchCV`.
#
# - Обучите новый `StandardScaler` на обучающей выборке (со всеми исходными признаками), прмиените масштабирование к тестовой выборке
# - В `GridSearchCV` укажите  cv=3.

# %%
# Ваш код здесь
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
svc = LinearSVC(random_state=RANDOM_STATE)
svc_params = {'C': [0.001, 0.01, 0.1, 1, 10]}

# %%
# Ваш код здесь
best_svc = GridSearchCV(svc, svc_params, n_jobs=4, cv=3, verbose=1)
best_svc.fit(X_train_scaled, y_train)
# Out:
# Fitting 3 folds for each of 5 candidates, totalling 15 fits
# ERROR:root:code for hash blake2b was not found.
# Traceback (most recent call last):
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 245, in <module>
#     globals()[__func_name] = __get_hash(__func_name)
#                              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 129, in __get_openssl_constructor
#     return __get_builtin_constructor(name)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 123, in __get_builtin_constructor
#     raise ValueError('unsupported hash type ' + name)
# ValueError: unsupported hash type blake2b
# ERROR:root:code for hash blake2s was not found.
# Traceback (most recent call last):
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 245, in <module>
#     globals()[__func_name] = __get_hash(__func_name)
#                              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 129, in __get_openssl_constructor
#     return __get_builtin_constructor(name)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 123, in __get_builtin_constructor
#     raise ValueError('unsupported hash type ' + name)
# ValueError: unsupported hash type blake2s
# ERROR:root:code for hash blake2b was not found.
# Traceback (most recent call last):
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 245, in <module>
#     globals()[__func_name] = __get_hash(__func_name)
#                              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 129, in __get_openssl_constructor
#     return __get_builtin_constructor(name)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 123, in __get_builtin_constructor
#     raise ValueError('unsupported hash type ' + name)
# ValueError: unsupported hash type blake2b
# ERROR:root:code for hash blake2s was not found.
# Traceback (most recent call last):
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 245, in <module>
#     globals()[__func_name] = __get_hash(__func_name)
#                              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 129, in __get_openssl_constructor
#     return __get_builtin_constructor(name)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 123, in __get_builtin_constructor
#     raise ValueError('unsupported hash type ' + name)
# ValueError: unsupported hash type blake2s
# ERROR:root:code for hash blake2b was not found.
# Traceback (most recent call last):
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 245, in <module>
#     globals()[__func_name] = __get_hash(__func_name)
#                              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 129, in __get_openssl_constructor
#     return __get_builtin_constructor(name)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 123, in __get_builtin_constructor
#     raise ValueError('unsupported hash type ' + name)
# ValueError: unsupported hash type blake2b
# ERROR:root:code for hash blake2s was not found.
# Traceback (most recent call last):
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 245, in <module>
#     globals()[__func_name] = __get_hash(__func_name)
#                              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 129, in __get_openssl_constructor
#     return __get_builtin_constructor(name)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 123, in __get_builtin_constructor
#     raise ValueError('unsupported hash type ' + name)
# ValueError: unsupported hash type blake2s
# ERROR:root:code for hash blake2b was not found.
# Traceback (most recent call last):
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 245, in <module>
#     globals()[__func_name] = __get_hash(__func_name)
#                              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 129, in __get_openssl_constructor
#     return __get_builtin_constructor(name)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 123, in __get_builtin_constructor
#     raise ValueError('unsupported hash type ' + name)
# ValueError: unsupported hash type blake2b
# ERROR:root:code for hash blake2s was not found.
# Traceback (most recent call last):
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 245, in <module>
#     globals()[__func_name] = __get_hash(__func_name)
#                              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 129, in __get_openssl_constructor
#     return __get_builtin_constructor(name)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/k1/.pyenv/versions/3.12.5/lib/python3.12/hashlib.py", line 123, in __get_builtin_constructor
#     raise ValueError('unsupported hash type ' + name)
# ValueError: unsupported hash type blake2s
# /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages/sklearn/svm/_base.py:1235: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages/sklearn/svm/_base.py:1235: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/k1/.pyenv/versions/3.12.5/lib/python3.12/site-packages/sklearn/svm/_base.py:1235: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# GridSearchCV(cv=3, estimator=LinearSVC(random_state=17), n_jobs=4,
#              param_grid={'C': [0.001, 0.01, 0.1, 1, 10]}, verbose=1)

# %%
best_svc.best_params_, best_svc.best_score_
# Out:
# ({'C': 0.1}, np.float64(0.9379785010699506))

# %% [markdown]
# **Вопрос 7**<br>
# Какое значение гиперпараметра `C` было выбрано лучшим по итогам кросс-валидации?<br>
#
# **Ответ:**
# - 0.001
# - 0.01
# - 0.1 [+]
# - 1
# - 10

# %%
y_predicted = best_svc.predict(X_test_scaled)

# %%
tab = pd.crosstab(y_test, y_predicted, margins=True)
tab.index = ['ходьба', 'подъем вверх по лестнице', 'спуск по лестнице', 
             'сидение', 'стояние', 'лежание', 'все']
tab.columns = tab.index
tab
# Out:
#                           ходьба  подъем вверх по лестнице  спуск по лестнице  \
# ходьба                       494                         2                  0
# подъем вверх по лестнице      12                       459                  0
# спуск по лестнице              2                         4                413
# сидение                        0                         4                  0
# стояние                        0                         0                  0
# лежание                        0                         0                  0
# все                          508                       469                413
#
#                           сидение  стояние  лежание   все
# ходьба                          0        0        0   496
# подъем вверх по лестнице        0        0        0   471
# спуск по лестнице               1        0        0   420
# сидение                       426       61        0   491
# стояние                        15      517        0   532
# лежание                         0       11      526   537
# все                           442      589      526  2947

# %% [markdown]
# **Вопрос 8:**<br>
# Какой вид активности SVM определяет хуже всего в терминах точности? Полноты? <br>
#
# **Ответ:**
# - по точности – подъем вверх по лестнице, по полноте – лежание
# - по точности – лежание, по полноте – сидение
# - по точности – ходьба, по полноте – ходьба
# - по точности – сидение, по полноте – стояние [+]

# %% [markdown]
# Наконец, проделайте то же самое, что в 7 вопросе, только добавив PCA.
#
# - Используйте выборки `X_train_scaled` и `X_test_scaled`
# - Обучите тот же PCA, что раньше, на отмасшабированной обучающей выборке, примените преобразование к тестовой
# - Настройте гиперпараметр `C` на кросс-валидации по обучающей выборке с PCA-преобразованием. Вы заметите, насколько это проходит быстрее, чем раньше.
#
# **Вопрос 9:**<br>
# Какова разность между лучшим качеством (долей верных ответов) на кросс-валидации в случае всех 561 исходных признаков и во втором случае, когда применялся метод главных компонент? Округлите до целых процентов.<br>
#
# **Варианты:**
# - Качество одинаковое
# - 2%
# - 4% [+]
# - 10%
# - 20%

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

pca = PCA(n_components=0.9, random_state=RANDOM_STATE)
X_train_pca = pca.fit_transform(X_train_scaled)
X_test_pca = pca.transform(X_test_scaled)

# %%
svc = LinearSVC(random_state=RANDOM_STATE)
svc_params = {"C": [0.001, 0.01, 0.1, 1, 10]}

# %%
best_svc_pca = GridSearchCV(svc, svc_params, n_jobs=4, cv=3, verbose=1)
best_svc_pca.fit(X_train_pca, y_train)
# Out:
# Fitting 3 folds for each of 5 candidates, totalling 15 fits
# GridSearchCV(cv=3, estimator=LinearSVC(random_state=17), n_jobs=4,
#              param_grid={'C': [0.001, 0.01, 0.1, 1, 10]}, verbose=1)

# %%
best_svc_pca.best_params_, best_svc_pca.best_score_
# Out:
# ({'C': 0.1}, np.float64(0.8983982658750974))

# %%
round(100 * (best_svc_pca.best_score_ - best_svc.best_score_))
# Out:
# -4

# %% [markdown]
# **Вопрос 10:**<br>
# Выберите все верные утверждения:
#
# **Варианты:**
# - Метод главных компонент в данном случае позволил уменьшить время обучения модели, при этом качество (доля верных ответов на кросс-валидации) очень пострадало, более чем на 10%
# - PCA можно использовать для визуализации данных, однако для этой задачи есть и лучше подходящие методы, например, tSNE. Зато PCA имеет меньшую вычислительную сложность [+]
# - PCA строит линейные комбинации исходных признаков, и в некоторых задачах они могут плохо интерпретироваться человеком [+]
